# %% [markdown]
# ## https://medmnist.com/

# %%
import matplotlib.pyplot as plt
import medmnist
from medmnist import PneumoniaMNIST  
from torchvision import transforms

train_dataset = PneumoniaMNIST(split='train', transform=transforms.ToTensor(), download=True)
num_images = 5

fig, axes = plt.subplots(1, num_images, figsize=(12, 4))

for i in range(num_images):
    img, label = train_dataset[i]
    img = img.permute(1, 2, 0).numpy()
    axes[i].imshow(img, cmap='gray')
    axes[i].set_title(f'Label: {label}')
    axes[i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Downloading https://zenodo.org/records/10519652/files/pneumoniamnist.npz?download=1 to C:\Users\sseyedka\.medmnist\pneumoniamnist.npz
# 100%|██████████| 4.17M/4.17M [00:01<00:00, 2.66MB/s]
